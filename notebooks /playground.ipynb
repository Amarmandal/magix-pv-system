# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10, 20, 30, 40, 50, 60, 70, 80])

cut = pd.cut(s, bins=[s.min(), 40, s.max()], labels=["Young", "Old"], right=False, index=s.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 s = pd.Series([10, 20, 30, 40, 50, 60, 70, 80])
#       2
# ----> 3 cut = pd.cut(s, bins=[s.min(), 40, s.max()], labels=["Young", "Old"], right=False, index=s.index)
#
# TypeError: cut() got an unexpected keyword argument 'index'

# %%
# Out:
# 0    Young
# 1    Young
# 2    Young
# 3      Old
# 4      Old
# dtype: category
# Categories (2, str): ['Young' < 'Old']
