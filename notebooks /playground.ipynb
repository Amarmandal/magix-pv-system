# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10, 20, 30, 40, 50, 60, 70, 80])

cut = pd.cut(s, bins=[s.min(), 40, s.max()], labels=["Young", "Old"], right=False)

# %%
cut
# Out:
# 0    Young
# 1    Young
# 2    Young
# 3      Old
# 4      Old
# 5      Old
# 6      Old
# 7      NaN
# dtype: category
# Categories (2, str): ['Young' < 'Old']

# %%
import json

# %%
with open("../data/processed/splits.json", "r") as fp: 
    obj = json.load(fp)

obj["created"]
# Out:
# '2026-07-24T20:54:51+00:00'

# %%
obj["clients"]
# Out:
# {'19477f81a2058c850a09310b7795fd4f': {'train_end': '2025-04-17T19:00:00',
#   'val_end': '2025-05-14T10:00:00',
#   'n_total': 2470,
#   'counts': {'train': 1729, 'val': 370, 'test': 371},
#   'ranges': {'train': ['2024-12-31T23:00:00', '2025-04-17T18:00:00'],
#    'val': ['2025-04-17T19:00:00', '2025-05-14T09:00:00'],
#    'test': ['2025-05-14T10:00:00', '2025-05-31T23:00:00']}},
#  '2c85da17f3ac504327da04874ef1a701': {'train_end': '2025-02-19T11:00:00',
#   'val_end': '2025-04-13T12:00:00',
#   'n_total': 6799,
#   'counts': {'train': 4759, 'val': 1020, 'test': 1020},
#   'ranges': {'train': ['2024-06-27T12:00:00', '2025-02-19T10:00:00'],
#    'val': ['2025-02-19T11:00:00', '2025-04-13T11:00:00'],
#    'test': ['2025-04-13T12:00:00', '2025-05-31T23:00:00']}},
#  '55cddba5799e63f231eae0eb8cca8247': {'train_end': '2025-04-28T10:00:00',
#   'val_end': '2025-05-15T06:00:00',
#   'n_total': 1789,
#   'counts': {'train': 1252, 'val': 268, 'test': 269},
#   'ranges': {'train': ['2024-12-31T23:00:00', '2025-04-28T09:00:00'],
#    'val': ['2025-04-28T10:00:00', '2025-05-15T05:00:00'],
#    'test': ['2025-05-15T06:00:00', '2025-05-31T18:00:00']}},
#  '7534daaee746a48bc5b99132810f3e69': {'train_end': '2025-04-28T16:00:00',
#   'val_end': '2025-05-15T09:00:00',
#   'n_total': 1769,
#   'counts': {'train': 1238, 'val': 265, 'test': 266},
#   'ranges': {'train': ['2024-12-31T23:00:00', '2025-04-28T15:00:00'],
#    'val': ['2025-04-28T16:00:00', '2025-05-15T08:00:00'],
#    'test': ['2025-05-15T09:00:00', '2025-05-31T18:00:00']}},
#  'ae68bd65b1c87d7a5985d1d5498442af': {'train_end': '2025-05-01T10:00:00',
#   'val_end': '2025-05-16T14:00:00',
#   'n_total': 1627,
#   'counts': {'train': 1138, 'val': 244, 'test': 245},
#   'ranges': {'train': ['2025-01-01T05:00:00', '2025-05-01T09:00:00'],
#    'val': ['2025-05-01T10:00:00', '2025-05-16T13:00:00'],
#    'test': ['2025-05-16T14:00:00', '2025-05-31T18:00:00']}},
#  'b59685487a1fc5712e03c264f70cb656': {'train_end': '2025-04-28T16:00:00',
#   'val_end': '2025-05-15T09:00:00',
#   'n_total': 1770,
#   'counts': {'train': 1239, 'val': 265, 'test': 266},
#   'ranges': {'train': ['2024-12-31T23:00:00', '2025-04-28T15:00:00'],
#    'val': ['2025-04-28T16:00:00', '2025-05-15T08:00:00'],
#    'test': ['2025-05-15T09:00:00', '2025-05-31T18:00:00']}},
#  'e2afd8af435a86d8bfe72dcbe937a5d6': {'train_end': '2025-04-29T03:00:00',
#   'val_end': '2025-05-15T11:00:00',
#   'n_total': 1759,
#   'counts': {'train': 1231, 'val': 264, 'test': 264},
#   'ranges': {'train': ['2024-12-31T23:00:00', '2025-04-28T18:00:00'],
#    'val': ['2025-04-29T03:00:00', '2025-05-15T10:00:00'],
#    'test': ['2025-05-15T11:00:00', '2025-05-31T18:00:00']}}}
